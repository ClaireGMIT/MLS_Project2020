# %% [markdown]
# Option 1 : https://blog.eduonix.com/artificial-intelligence/explore-neural-networks-scikit-learn/

# %% [markdown]
# # Machine Learning and Statisitics 2020
#
# ## Project 2020
#
# ### Student ID: Claire Nolan G00376464

# %%
# Neural networks.
import tensorflow.keras as kr

# Numerical arrays
import numpy as np

# Data frames.
import pandas as pd

# Plotting
import matplotlib.pyplot as plt

import seaborn as sns

import sklearn as sk
import sklearn.cluster as skcl
from sklearn.model_selection import train_test_split

# %%
# Plot style.
plt.style.use("ggplot")

# Plot size.
plt.rcParams['figure.figsize'] = [14, 8]

# %%
# Import the dataset

df = pd.read_csv("https://raw.githubusercontent.com/ClaireGMIT/MLS_Project2020/main/powerproduction.csv")
df[["speed", "power"]][0:4]
# Out:
#    speed  power
# 0  0.000    0.0
# 1  0.125    0.0
# 2  0.150    0.0
# 3  0.225    0.0

# %%
df.plot(x="speed", y="power")
plt.show()

# %%
df.describe()
# Out:
#             speed       power
# count  500.000000  500.000000
# mean    12.590398   48.014584
# std      7.224991   41.614572
# min      0.000000    0.000000
# 25%      6.324750    5.288000
# 50%     12.550500   41.645500
# 75%     18.775250   93.537000
# max     25.000000  113.556000

# %%
import sklearn

## import the iris dataset for classification

#df = x, y



## print some data, to see the imported dataset

#print("Printing some sample data from the iris dataset")
#for training_sample in list(zip(df.data,df.target))[:5]:
#    print(training_sample)

## save the features and class

#features=df.speed   	# split iris dataset into features and iris_class
#df_class=df.target  # class[X] is output corresponding to features[X]

# %%
#wind=df.data   	# split iris dataset into wind and speed_class
#speed_class=speed.target  # class[X] is output corresponding to wind[X]




#print("Splitting the data into testing and training samples")
#from sklearn.model_selection import train_test_split
#["speed", "power"]

#(x_train, x_test), (y_train, y_test) = sk.model_selection.train_test_split(x,y, test_size=0.2, train_size=0.8, stratify=None)

#(x_train, x_test), (y_train, y_test) =train_test_split(x,y,stratify=y, train_size=.8, random_state=42)
#y.shape

#, test_size=0.2, train_size=0.8, random_state=None, shuffle=True, stratify=None


#(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
# Option 1

#x = df[["speed"]]
#y = df[["power"]]

sk.model_selection.train_test_split(x,y, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
# Out:
# [      speed
#  423  21.121
#  169   8.408
#  95    5.080
#  277  14.189
#  182   9.309
#  ..      ...
#  258  12.888
#  242  12.287
#  6     0.400
#  164   8.083
#  49    2.477
#
#  [375 rows x 1 columns],
#        speed
#  241  12.262
#  430  21.622
#  149   7.432
#  409  20.270
#  142   7.182
#  ..      ...
#  391  19.620
#  114   5.931
#  194   9.985
#  143   7.207
#  283  14.489
#
#  [125 rows x 1 columns],
#         power
#  423  101.212
#  169    6.656
#  95     2.973
#  277   67.263
#  182   12.881
#  ..       ...
#  258   53.954
#  242   43.454
#  6      5.186
#  164    5.385
#  49     6.947
#
#  [375 rows x 1 columns],
#         power
#  241   46.136
#  430  103.433
#  149    0.000
#  409   95.012
#  142    0.067
#  ..       ...
#  391   91.501
#  114    0.000
#  194   19.354
#  143    8.238
#  283   71.763
#
#  [125 rows x 1 columns]]

# %%
## data preprocessing: Before training the network we must scale the feature data
#print("Data preprocessing")
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#scaler.fit(x_train)
#x_train_scale = scaler.transform(x_train)
#x_test_scale = scaler.transform(x_test)

# %%
## The MLPClassifier and MLPRegressor are sklearn implementations of NNs

from sklearn.neural_network import MLPClassifier
iterations=1000   # define the iterations for training over the dataset
hidden_layers=[10,10,10]  # define the layers/depth of the NN
#print("Creating a neural network with" layers and  iterations)

mlp = MLPClassifier(hidden_layer_sizes=(hidden_layers), max_iter=iterations)

# %%
# an object which represents the neural network
# Remember to use the pre-processed data and not original values for fit()

mlp.fit(x_train, y_train)  # fit features over NN

## Run the test data over the network to see the predicted outcomes.

predicted = mlp.predict(x_test)  

# predict over test data
## evaluation metrics and analysing the accuracy/output.
#print("Evaluation: considering the confusion matrix")
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y,predicted))  
# all non-diagonal elements are 0 if you get 100% accuracy

#print("Evaluation report:")
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted)) 
#f1-score/accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-13914c7ccb92> in <module>
#       2 # Remember to use the pre-processed data and not original values for fit()
#       3
# ----> 4 mlp.fit(x_train, y_train)  # fit features over NN
#       5
#       6 ## Run the test data over the network to see the predicted outcomes.
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#    1026         """
#    1027         return self._fit(X, y, incremental=(self.warm_start and
# -> 1028                                             hasattr(self, "classes_")))
#    1029
#    1030     @property
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     324                              hidden_layer_sizes)
#     325
# ...
